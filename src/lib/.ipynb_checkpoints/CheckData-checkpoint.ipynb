# %%
from library import *
import os
import re
import pandas as pd
from pandas import Series
from pandas import DataFrame
import json
from io import StringIO
from

# %%
def extract_para_and_station(file_path):
    """
    First three lines describe the fuke, fourth line describe schema, others for data
    :param file_path:
    :return:
    """

    with open(file_path) as input:
        # Read weather para, lon and lat from the first line
        line = input.readline()
        line = line.replace('"', '')
        line = re.sub("[\(\[].*?[\)\]]", "", line)
        segs = line.split(',')
        segs = [seg.strip() for seg in segs]
        weather = '_'.join(segs[0].lower().split(' '))
        lat = segs[1].split('=')[1]
        lon = segs[2].split('=')[1]

        # Read station from the second line
        line = input.readline()
        line = line.replace('"', '')
        segs = line.split(':')
        segs = [seg.strip() for seg in segs]
        station_code = segs[1]
        return {'weather': weather, 'lat': lat, 'lon': lon, 'station_code': station_code}

# %%
def generate_panda_dataframe(file_path):
    file_config = extract_para_and_station(file_path)
    with open(file_path) as input:

        df = pd.read_csv(StringIO(input.read()), skiprows=4, header=None)  
        if file_config['weather'] != 'wind':
            df = df[[0,2]]
            df.columns = ['time', file_config['weather']]
            df = df.assign(station_code = [file_config['station_code'] for _ in range(len(df))]) 
            
        else:
            df = df[[0,2,3]]
            df.columns = ['time','wind_speed', 'wind_direction']
            df = df.assign(station_code = [file_config['station_code'] for _ in range(len(df))])  
        return df, file_config

# %%
files = read_all_files()
source_df = DataFrame()
num = 3
station_df_map = {}
station_config_map = {}
dfs = []
total_number = 0
for file in files:
    config = extract_para_and_station(file)
    if config['weather'] == 'wind_direction':
   
        df, _ = generate_panda_dataframe(file)
        dfs.append(df)
        print('filename', '/'.join(file.split('/')[-2:]))
        print(len(df[df.wind_direction < 0]))
        total_number += len(df[df.wind_direction < 0])
print(total_number)
#     print(file.split('/')[-1],extract_para_and_station(file))
    
#     df, file_config = generate_panda_dataframe(file)
#     station_code = file_config['station_code']
#     station_config_map[station_code] = [float(file_config['lon']), float(file_config['lat'])]
#     print(station_code)
#     if station_code not in station_df_map:
#         station_df_map[station_code] = []
#     station_df_map[station_code].append(df)
# Out:
# filename temperature_20160601_20061231/SH_TEMP_222142_1142186.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223186_1142247.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_225364_1143019.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224111_1141247.csv
# 178
# filename temperature_20160601_20061231/SH_TEMP_225306_1141536.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223094_1139219.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223111_1142108.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223036_1141719.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222911_1139069.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223358_1141369.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222483_1141708.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224706_1139811.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223703_1143125.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_225019_1141111.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222661_1141528.csv
# 49
# filename temperature_20160601_20061231/SH_TEMP_224768_1142351.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224729_1143582.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223594_1142153.csv
# 152
# filename temperature_20160601_20061231/SH_TEMP_222011_1140267.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223394_1142053.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224031_1143233.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223379_1142675.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224667_1140089.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223158_1142556.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223500_1141067.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222783_1141622.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223350_1141847.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224339_1140850.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223369_1142690.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222817_1142361.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222706_1141836.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_222600_1139000.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223132_1141704.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224031_1142086.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_225482_1144258.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_224458_1141789.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223328_1142670.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223922_1139742.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223353_1142648.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223370_1142690.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_223772_1142717.csv
# 0
# filename temperature_20160601_20061231/SH_TEMP_221836_1143006.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222142_1142186.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223186_1142247.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_225364_1143019.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224111_1141247.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_225306_1141536.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223094_1139219.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223111_1142108.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223036_1141719.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222860_1139338.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222911_1139069.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223358_1141369.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222483_1141708.csv
# 6
# filename temperature_20170101_20170630/SH_TEMP_224706_1139811.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223703_1143125.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_225019_1141111.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222661_1141528.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224768_1142351.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224729_1143582.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223328_1142670 (1).csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223594_1142153.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222011_1140267.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223394_1142053.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224031_1143233.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224667_1140089.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223158_1142556.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223500_1141067.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222783_1141622.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223350_1141847.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224450_1140230.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224339_1140850.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222817_1142361.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222706_1141836.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_222600_1139000.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223132_1141704.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224031_1142086.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_225482_1144258.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_224458_1141789.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223328_1142670.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223922_1139742.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_223772_1142717.csv
# 0
# filename temperature_20170101_20170630/SH_TEMP_221836_1143006.csv
# 0
# 385
