# %%
from library import *
import os
import re
import pandas as pd
from pandas import Series
from pandas import DataFrame
import json
from io import StringIO

client = MongoClient('127.0.0.1', 27017)

db = client['air_quality_model_hkust']
sub_hour_weather_collection_name = 'subhour_weather_hkust'
sub_hour_weather_collection = db[sub_hour_weather_collection_name]

# %%
def init_collection():
    indexs = []
    if sub_hour_weather_collection_name not in db.collection_names():
        sub_hour_weather_collection.create_index('time')
        sub_hour_weather_collection.create_index([("loc", pymongo.GEOSPHERE)])
    else:
        for index_agg in sub_hour_weather_collection.index_information():
            indexs.append(index_agg.split("_")[0])
        if 'time' not in indexs:
            sub_hour_weather_collection.create_index('time')
        if 'loc' not in indexs:
            sub_hour_weather_collection.create_index([("loc", pymongo.GEOSPHERE)])

# %%
def extract_para_and_station(file_path):
    """
    First three lines describe the fuke, fourth line describe schema, others for data
    :param file_path:
    :return:
    """

    with open(file_path) as input:
        # Read weather para, lon and lat from the first line
        line = input.readline()
        line = line.replace('"', '')
        line = re.sub("[\(\[].*?[\)\]]", "", line)
        segs = line.split(',')
        segs = [seg.strip() for seg in segs]
        weather = '_'.join(segs[0].lower().split(' '))
        lat = segs[1].split('=')[1]
        lon = segs[2].split('=')[1]

        # Read station from the second line
        line = input.readline()
        line = line.replace('"', '')
        segs = line.split(':')
        segs = [seg.strip() for seg in segs]
        station_code = segs[1]
        return {'weather': weather, 'lat': lat, 'lon': lon, 'station_code': station_code}

# %%
def parser_context_line(line, weather):
    segs = line.split(',')
    segs = [seg.strip() for seg in segs]
    parse_result = {}
    time_stamp = time.strptime(segs[0], "%Y/%m/%d %H:%M:%S")
    time_stamp = time.mktime(time_stamp)
    parse_result['time'] = time_stamp
    if weather != "wind":
        parse_result[weather] = segs[2]
    else:
        parse_result['wind_speed'] = segs[2]
        parse_result['wind_direction'] = segs[3]

    return parse_result

# %%
def generate_panda_dataframe(file_path):
    file_config = extract_para_and_station(file_path)
    with open(file_path) as input:

        df = pd.read_csv(StringIO(input.read()), skiprows=4, header=None)  
        if file_config['weather'] != 'wind':
            df = df[[0,2]]
            df.columns = ['time', file_config['weather']]
            df = df.assign(station_code = [file_config['station_code'] for _ in range(len(df))]) 
            
        else:
            df = df[[0,2,3]]
            df.columns = ['time','wind_speed', 'wind_direction']
            df = df.assign(station_code = [file_config['station_code'] for _ in range(len(df))])  
        return df, file_config

# %%
files = read_all_files()
source_df = DataFrame()
num = 3
station_df_map = {}
station_config_map = {}
for file in files:
    print(file.split('/')[-1])

    df, file_config = generate_panda_dataframe(file)
    station_code = file_config['station_code']
    station_config_map[station_code] = [float(file_config['lon']), float(file_config['lat'])]
    print(station_code)
    if station_code not in station_df_map:
        station_df_map[station_code] = []
    station_df_map[station_code].append(df)
    
print(station_config_map)
# Out:
# SH_RH_221836_1143006.csv
# WGL_AWS
# SH_RH_222011_1140267.csv
# CCH_AWS
# SH_RH_222483_1141708.csv
# HKS_AWS
# SH_RH_222911_1139069.csv
# SLW_AWS
# SH_RH_223036_1141719.csv
# HKO_AWS
# SH_RH_223094_1139219.csv
# HKA_AWS
# SH_RH_223132_1141704.csv
# KP_AWS
# SH_RH_223158_1142556.csv
# JKB_AWS
# SH_RH_223353_1142648.csv
# USTTB
# SH_RH_223369_1142690.csv
# USTPR
# SH_RH_223370_1142690.csv
# USTPR2
# SH_RH_223379_1142675.csv
# PHSUP
# SH_RH_223500_1141067.csv
# CPH_AWS
# SH_RH_223594_1142153.csv
# TC_AWS
# SH_RH_223703_1143125.csv
# KSC_AWS
# SH_RH_223772_1142717.csv
# SKG_AWS
# SH_RH_223922_1139742.csv
# TUN_AWS
# SH_RH_224031_1142086.csv
# SHA_AWS
# SH_RH_224031_1143233.csv
# TYW_AWS
# SH_RH_224111_1141247.csv
# TMS_AWS
# SH_RH_224339_1140850.csv
# SEK_AWS
# SH_RH_224458_1141789.csv
# TPO_AWS
# SH_RH_224667_1140089.csv
# WLP_AWS
# SH_RH_224706_1139811.csv
# LFS_AWS
# SH_RH_225019_1141111.csv
# SSH_AWS
# SH_RH_225306_1141536.csv
# TKL_AWS
# SH_RH_225482_1144258.csv
# EPC_AWS
# SH_RH_221836_1143006.csv
# WGL_AWS
# SH_RH_222011_1140267.csv
# CCH_AWS
# SH_RH_222483_1141708.csv
# HKS_AWS
# SH_RH_222860_1139338.csv
# TCAWS
# SH_RH_222911_1139069.csv
# SLW_AWS
# SH_RH_223036_1141719.csv
# HKO_AWS
# SH_RH_223094_1139219.csv
# HKA_AWS
# SH_RH_223132_1141704.csv
# KP_AWS
# SH_RH_223158_1142556.csv
# JKB_AWS
# SH_RH_223328_1142670.csv
# PHSUP2
# SH_RH_223500_1141067.csv
# CPH_AWS
# SH_RH_223594_1142153.csv
# TC_AWS
# SH_RH_223703_1143125.csv
# KSC_AWS
# SH_RH_223772_1142717.csv
# SKG_AWS
# SH_RH_223922_1139742.csv
# TUN_AWS
# SH_RH_224031_1142086.csv
# SHA_AWS
# SH_RH_224031_1143233.csv
# TYW_AWS
# SH_RH_224111_1141247.csv
# TMS_AWS
# SH_RH_224339_1140850.csv
# SEK_AWS
# SH_RH_224450_1140230.csv
# YLAWS
# SH_RH_224458_1141789.csv
# TPO_AWS
# SH_RH_224667_1140089.csv
# WLP_AWS
# SH_RH_224706_1139811.csv
# LFS_AWS
# SH_RH_225019_1141111.csv
# SSH_AWS
# SH_RH_225306_1141536.csv
# TKL_AWS
# SH_RH_225482_1144258.csv
# EPC_AWS
# SH_TEMP_221836_1143006.csv
# WGL_AWS
# SH_TEMP_222011_1140267.csv
# CCH_AWS
# SH_TEMP_222142_1142186.csv
# STL_AWS
# SH_TEMP_222483_1141708.csv
# HKS_AWS
# SH_TEMP_222600_1139000.csv
# NGP_AWS
# SH_TEMP_222661_1141528.csv
# VP1_AWS
# SH_TEMP_222706_1141836.csv
# HPV_AWS
# SH_TEMP_222783_1141622.csv
# HKP_AWS
# SH_TEMP_222817_1142361.csv
# SKW_AWS
# SH_TEMP_222911_1139069.csv
# SLW_AWS
# SH_TEMP_223036_1141719.csv
# HKO_AWS
# SH_TEMP_223094_1139219.csv
# HKA_AWS
# SH_TEMP_223111_1142108.csv
# SE_AWS
# SH_TEMP_223132_1141704.csv
# KP_AWS
# SH_TEMP_223158_1142556.csv
# JKB_AWS
# SH_TEMP_223186_1142247.csv
# KWT_AWS
# SH_TEMP_223328_1142670.csv
# PHSUP2
# SH_TEMP_223350_1141847.csv
# KLC_AWS
# SH_TEMP_223353_1142648.csv
# USTTB
# SH_TEMP_223358_1141369.csv
# SSP_AWS
# SH_TEMP_223369_1142690.csv
# USTPR
# SH_TEMP_223370_1142690.csv
# USTPR2
# SH_TEMP_223379_1142675.csv
# PHSUP
# SH_TEMP_223394_1142053.csv
# WTS_AWS
# SH_TEMP_223500_1141067.csv
# CPH_AWS
# SH_TEMP_223594_1142153.csv
# TC_AWS
# SH_TEMP_223703_1143125.csv
# KSC_AWS
# SH_TEMP_223772_1142717.csv
# SKG_AWS
# SH_TEMP_223922_1139742.csv
# TUN_AWS
# SH_TEMP_224031_1142086.csv
# SHA_AWS
# SH_TEMP_224031_1143233.csv
# TYW_AWS
# SH_TEMP_224111_1141247.csv
# TMS_AWS
# SH_TEMP_224339_1140850.csv
# SEK_AWS
# SH_TEMP_224458_1141789.csv
# TPO_AWS
# SH_TEMP_224667_1140089.csv
# WLP_AWS
# SH_TEMP_224706_1139811.csv
# LFS_AWS
# SH_TEMP_224729_1143582.csv
# TAP_AWS
# SH_TEMP_224768_1142351.csv
# PLC_AWS
# SH_TEMP_225019_1141111.csv
# SSH_AWS
# SH_TEMP_225306_1141536.csv
# TKL_AWS
# SH_TEMP_225364_1143019.csv
# KAT_AWS
# SH_TEMP_225482_1144258.csv
# EPC_AWS
# SH_TEMP_221836_1143006.csv
# WGL_AWS
# SH_TEMP_222011_1140267.csv
# CCH_AWS
# SH_TEMP_222142_1142186.csv
# STL_AWS
# SH_TEMP_222483_1141708.csv
# HKS_AWS
# SH_TEMP_222600_1139000.csv
# NGP_AWS
# SH_TEMP_222661_1141528.csv
# VP1_AWS
# SH_TEMP_222706_1141836.csv
# HPV_AWS
# SH_TEMP_222783_1141622.csv
# HKP_AWS
# SH_TEMP_222817_1142361.csv
# SKW_AWS
# SH_TEMP_222860_1139338.csv
# TCAWS
# SH_TEMP_222911_1139069.csv
# SLW_AWS
# SH_TEMP_223036_1141719.csv
# HKO_AWS
# SH_TEMP_223094_1139219.csv
# HKA_AWS
# SH_TEMP_223111_1142108.csv
# SE_AWS
# SH_TEMP_223132_1141704.csv
# KP_AWS
# SH_TEMP_223158_1142556.csv
# JKB_AWS
# SH_TEMP_223186_1142247.csv
# KWT_AWS
# SH_TEMP_223328_1142670 (1).csv
# PHSUP2
# SH_TEMP_223328_1142670.csv
# PHSUP2
# SH_TEMP_223350_1141847.csv
# KLC_AWS
# SH_TEMP_223358_1141369.csv
# SSP_AWS
# SH_TEMP_223394_1142053.csv
# WTS_AWS
# SH_TEMP_223500_1141067.csv
# CPH_AWS
# SH_TEMP_223594_1142153.csv
# TC_AWS
# SH_TEMP_223703_1143125.csv
# KSC_AWS
# SH_TEMP_223772_1142717.csv
# SKG_AWS
# SH_TEMP_223922_1139742.csv
# TUN_AWS
# SH_TEMP_224031_1142086.csv
# SHA_AWS
# SH_TEMP_224031_1143233.csv
# TYW_AWS
# SH_TEMP_224111_1141247.csv
# TMS_AWS
# SH_TEMP_224339_1140850.csv
# SEK_AWS
# SH_TEMP_224450_1140230.csv
# YLAWS
# SH_TEMP_224458_1141789.csv
# TPO_AWS
# SH_TEMP_224667_1140089.csv
# WLP_AWS
# SH_TEMP_224706_1139811.csv
# LFS_AWS
# SH_TEMP_224729_1143582.csv
# TAP_AWS
# SH_TEMP_224768_1142351.csv
# PLC_AWS
# SH_TEMP_225019_1141111.csv
# SSH_AWS
# SH_TEMP_225306_1141536.csv
# TKL_AWS
# SH_TEMP_225364_1143019.csv
# KAT_AWS
# SH_TEMP_225482_1144258.csv
# EPC_AWS
# SH_WIND_221836_1143006.csv
# WGL_AWS
# SH_WIND_221975_1142119.csv
# BHD_AWS
# SH_WIND_222011_1140267.csv
# CCH_AWS
# SH_WIND_222108_1140292.csv
# CCB_AWS
# SH_WIND_222142_1142186.csv
# STL_AWS
# SH_WIND_222483_1141708.csv
# HKS_AWS
# SH_WIND_222531_1138536.csv
# TO_AWS
# SH_WIND_222592_1139642.csv
# YTS_AWS
# SH_WIND_222600_1139000.csv
# NGP_AWS
# SH_WIND_222633_1139111.csv
# NLS_AWS
# SH_WIND_222867_1141103.csv
# GI_AWS
# SH_WIND_222911_1139069.csv
# SLW_AWS
# SH_WIND_222944_1141661.csv
# SF_AWS
# SH_WIND_222944_1141997.csv
# NP_AWS
# SH_WIND_223036_1141719.csv
# HKO_AWS
# SH_WIND_223058_1139792.csv
# SHW_AWS
# SH_WIND_223094_1139219.csv
# HKA_AWS
# SH_WIND_223111_1142108.csv
# SE_AWS
# SH_WIND_223132_1141704.csv
# KP_AWS
# SH_WIND_223158_1142556.csv
# JKB_AWS
# SH_WIND_223166_1139119.csv
# R2C_AWS
# SH_WIND_223297_1139667.csv
# TMT_AWS
# SH_WIND_223369_1142690 (1).csv
# USTPR
# SH_WIND_223369_1142690.csv
# USTPR
# SH_WIND_223379_1142675.csv
# PHSUP
# SH_WIND_223458_1138911.csv
# SC_AWS
# SH_WIND_223483_1140839.csv
# SHL_AWS
# SH_WIND_223500_1141067.csv
# CPH_AWS
# SH_WIND_223594_1142153.csv
# TC_AWS
# SH_WIND_223772_1142717.csv
# SKG_AWS
# SH_WIND_223922_1139742.csv
# TUN_AWS
# SH_WIND_224031_1142086.csv
# SHA_AWS
# SH_WIND_224111_1141247.csv
# TMS_AWS
# SH_WIND_224339_1140850.csv
# SEK_AWS
# SH_WIND_224425_1141842.csv
# TPK_AWS
# SH_WIND_224667_1140089.csv
# WLP_AWS
# SH_WIND_224706_1139811.csv
# LFS_AWS
# SH_WIND_224729_1143582.csv
# TAP_AWS
# SH_WIND_224768_1142351.csv
# PLC_AWS
# SH_WIND_225306_1141536.csv
# TKL_AWS
# SH_WIND_225482_1144258.csv
# EPC_AWS
# SH_WIND_221836_1143006.csv
# WGL_AWS
# SH_WIND_221975_1142119.csv
# BHD_AWS
# SH_WIND_222011_1140267.csv
# CCH_AWS
# SH_WIND_222108_1140292.csv
# CCB_AWS
# SH_WIND_222142_1142186.csv
# STL_AWS
# SH_WIND_222483_1141708.csv
# HKS_AWS
# SH_WIND_222531_1138536.csv
# TO_AWS
# SH_WIND_222592_1139642.csv
# YTS_AWS
# SH_WIND_222600_1139000.csv
# NGP_AWS
# SH_WIND_222633_1139111.csv
# NLS_AWS
# SH_WIND_222867_1141103.csv
# GI_AWS
# SH_WIND_222911_1139069.csv
# SLW_AWS
# SH_WIND_222944_1141661.csv
# SF_AWS
# SH_WIND_222944_1141997.csv
# NP_AWS
# SH_WIND_223036_1141719.csv
# HKO_AWS
# SH_WIND_223058_1139792.csv
# SHW_AWS
# SH_WIND_223094_1139219.csv
# HKA_AWS
# SH_WIND_223111_1142108.csv
# SE_AWS
# SH_WIND_223132_1141704.csv
# KP_AWS
# SH_WIND_223158_1142556.csv
# JKB_AWS
# SH_WIND_223166_1139119.csv
# R2C_AWS
# SH_WIND_223297_1139667.csv
# TMT_AWS
# SH_WIND_223328_1142670.csv
# PHSUP2
# SH_WIND_223379_1142680.csv
# SPAWS
# SH_WIND_223458_1138911.csv
# SC_AWS
# SH_WIND_223483_1140839.csv
# SHL_AWS
# SH_WIND_223500_1141067.csv
# CPH_AWS
# SH_WIND_223594_1142153.csv
# TC_AWS
# SH_WIND_223772_1142717.csv
# SKG_AWS
# SH_WIND_223922_1139742.csv
# TUN_AWS
# SH_WIND_224031_1142086.csv
# SHA_AWS
# SH_WIND_224111_1141247.csv
# TMS_AWS
# SH_WIND_224339_1140850.csv
# SEK_AWS
# SH_WIND_224425_1141842.csv
# TPK_AWS
# SH_WIND_224667_1140089.csv
# WLP_AWS
# SH_WIND_224706_1139811.csv
# LFS_AWS
# SH_WIND_224729_1143582.csv
# TAP_AWS
# SH_WIND_224768_1142351.csv
# PLC_AWS
# SH_WIND_225306_1141536.csv
# TKL_AWS
# SH_WIND_225482_1144258.csv
# EPC_AWS
# {'WGL_AWS': [114.3006, 22.1836], 'CCH_AWS': [114.0267, 22.2011], 'HKS_AWS': [114.1708, 22.2483], 'SLW_AWS': [113.9069, 22.2911], 'HKO_AWS': [114.1719, 22.3036], 'HKA_AWS': [113.9219, 22.3094], 'KP_AWS': [114.1704, 22.3132], 'JKB_AWS': [114.2556, 22.3158], 'USTTB': [114.2648, 22.3353], 'USTPR': [114.269, 22.3369], 'USTPR2': [114.269, 22.337], 'PHSUP': [114.2675, 22.3379], 'CPH_AWS': [114.1067, 22.35], 'TC_AWS': [114.2153, 22.3594], 'KSC_AWS': [114.3125, 22.3703], 'SKG_AWS': [114.2717, 22.3772], 'TUN_AWS': [113.9742, 22.3922], 'SHA_AWS': [114.2086, 22.4031], 'TYW_AWS': [114.3233, 22.4031], 'TMS_AWS': [114.1247, 22.4111], 'SEK_AWS': [114.085, 22.4339], 'TPO_AWS': [114.1789, 22.4458], 'WLP_AWS': [114.0089, 22.4667], 'LFS_AWS': [113.9811, 22.4706], 'SSH_AWS': [114.1111, 22.5019], 'TKL_AWS': [114.1536, 22.5306], 'EPC_AWS': [114.4258, 22.5482], 'TCAWS': [113.9338, 22.286], 'PHSUP2': [114.267, 22.3328], 'YLAWS': [114.023, 22.445], 'STL_AWS': [114.2186, 22.2142], 'NGP_AWS': [113.9, 22.26], 'VP1_AWS': [114.1528, 22.2661], 'HPV_AWS': [114.1836, 22.2706], 'HKP_AWS': [114.1622, 22.2783], 'SKW_AWS': [114.2361, 22.2817], 'SE_AWS': [114.2108, 22.3111], 'KWT_AWS': [114.2247, 22.3186], 'KLC_AWS': [114.1847, 22.335], 'SSP_AWS': [114.1369, 22.3358], 'WTS_AWS': [114.2053, 22.3394], 'TAP_AWS': [114.3582, 22.4729], 'PLC_AWS': [114.2351, 22.4768], 'KAT_AWS': [114.3019, 22.5364], 'BHD_AWS': [114.2119, 22.1975], 'CCB_AWS': [114.0292, 22.2108], 'TO_AWS': [113.8536, 22.2531], 'YTS_AWS': [113.9642, 22.2592], 'NLS_AWS': [113.9111, 22.2633], 'GI_AWS': [114.1103, 22.2867], 'SF_AWS': [114.1661, 22.2944], 'NP_AWS': [114.1997, 22.2944], 'SHW_AWS': [113.9792, 22.3058], 'R2C_AWS': [113.9119, 22.3166], 'TMT_AWS': [113.9667, 22.3297], 'SC_AWS': [113.8911, 22.3458], 'SHL_AWS': [114.0839, 22.3483], 'TPK_AWS': [114.1842, 22.4425], 'SPAWS': [114.268, 22.3379]}

# %%
for station_code in station_df_map:
    print(station_code, len(station_df_map[station_code]))
# Out:
# WGL_AWS 6
# CCH_AWS 6
# HKS_AWS 6
# SLW_AWS 6
# HKO_AWS 6
# HKA_AWS 6
# KP_AWS 6
# JKB_AWS 6
# USTTB 2
# USTPR 4
# USTPR2 2
# PHSUP 3
# CPH_AWS 6
# TC_AWS 6
# KSC_AWS 4
# SKG_AWS 6
# TUN_AWS 6
# SHA_AWS 6
# TYW_AWS 4
# TMS_AWS 6
# SEK_AWS 6
# TPO_AWS 4
# WLP_AWS 6
# LFS_AWS 6
# SSH_AWS 4
# TKL_AWS 6
# EPC_AWS 6
# TCAWS 2
# PHSUP2 5
# YLAWS 2
# STL_AWS 4
# NGP_AWS 4
# VP1_AWS 2
# HPV_AWS 2
# HKP_AWS 2
# SKW_AWS 2
# SE_AWS 4
# KWT_AWS 2
# KLC_AWS 2
# SSP_AWS 2
# WTS_AWS 2
# TAP_AWS 4
# PLC_AWS 4
# KAT_AWS 2
# BHD_AWS 2
# CCB_AWS 2
# TO_AWS 2
# YTS_AWS 2
# NLS_AWS 2
# GI_AWS 2
# SF_AWS 2
# NP_AWS 2
# SHW_AWS 2
# R2C_AWS 2
# TMT_AWS 2
# SC_AWS 2
# SHL_AWS 2
# TPK_AWS 2
# SPAWS 1

# %%
station_dfs_merge = {}
for station_code in station_df_map:
    dfs = station_df_map[station_code]
    print(station_code, len(dfs))
    source_df = DataFrame()
    start_time = time.time()
    for temp_df in dfs:
        temp_df = temp_df.drop_duplicates(subset = ['time', 'station_code'])
        if source_df.empty == True:
            source_df = temp_df   
        else:
            source_df = pd.merge(source_df, temp_df, how='outer', on=['time', 'station_code'], suffixes=('_c', '_c'))
            temp_df = temp_df.drop_duplicates(subset = ['time', 'station_code'])
        print(time.time() - start_time)
    station_dfs_merge[station_code] = source_df
# Out:
# WGL_AWS 6
# 0.030512571334838867
# 0.09750008583068848
# 0.1965012550354004
# 0.2779989242553711
# 0.37199878692626953
# 0.45149970054626465
# CCH_AWS 6
# 0.01949906349182129
# 0.08550071716308594
# 0.18249964714050293
# 0.2580227851867676
# 0.359999418258667
# 0.4485011100769043
# HKS_AWS 6
# 0.020502090454101562
# 0.08800148963928223
# 0.1990036964416504
# 0.27950048446655273
# 0.38252758979797363
# 0.4720020294189453
# SLW_AWS 6
# 0.011527299880981445
# 0.06049847602844238
# 0.13449835777282715
# 0.19299817085266113
# 0.2669999599456787
# 0.31099915504455566
# HKO_AWS 6
# 0.023029804229736328
# 0.09349966049194336
# 0.19352340698242188
# 0.2720015048980713
# 0.33099937438964844
# 0.386000394821167
# HKA_AWS 6
# 0.020998001098632812
# 0.10299992561340332
# 0.20799970626831055
# 0.2904982566833496
# 0.38199830055236816
# 0.4334986209869385
# KP_AWS 6
# 0.022501230239868164
# 0.1075286865234375
# 0.23450088500976562
# 0.31400299072265625
# 0.39300060272216797
# 0.4525306224822998
# JKB_AWS 6
# 0.01797175407409668
# 0.08247256278991699
# 0.18297171592712402
# 0.25997161865234375
# 0.3620026111602783
# 0.41747140884399414
# USTTB 2
# 0.05100131034851074
# 0.22149944305419922
# USTPR 4
# 0.10850071907043457
# 0.6015021800994873
# 0.7915284633636475
# 1.3155322074890137
# USTPR2 2
# 0.11899662017822266
# 0.6944975852966309
# PHSUP 3
# 0.007028102874755859
# 0.02403116226196289
# 0.04500102996826172
# CPH_AWS 6
# 0.02249932289123535
# 0.09099698066711426
# 0.19249701499938965
# 0.2725038528442383
# 0.3620264530181885
# 0.44402503967285156
# TC_AWS 6
# 0.010968446731567383
# 0.05647087097167969
# 0.1529688835144043
# 0.23647022247314453
# 0.34146833419799805
# 0.42349720001220703
# KSC_AWS 4
# 0.018472909927368164
# 0.08347153663635254
# 0.1644735336303711
# 0.22497081756591797
# SKG_AWS 6
# 0.01649951934814453
# 0.08299922943115234
# 0.17749953269958496
# 0.2630009651184082
# 0.36749911308288574
# 0.4615011215209961
# TUN_AWS 6
# 0.024999618530273438
# 0.09450984001159668
# 0.19449901580810547
# 0.2689993381500244
# 0.3575000762939453
# 0.43849992752075195
# SHA_AWS 6
# 0.0214993953704834
# 0.09150004386901855
# 0.20150279998779297
# 0.28200268745422363
# 0.3860468864440918
# 0.46849966049194336
# TYW_AWS 4
# 0.010000467300415039
# 0.05902433395385742
# 0.1620006561279297
# 0.23850202560424805
# TMS_AWS 6
# 0.016500473022460938
# 0.07849979400634766
# 0.1674976348876953
# 0.24202656745910645
# 0.30614733695983887
# 0.36302757263183594
# SEK_AWS 6
# 0.017936229705810547
# 0.0794370174407959
# 0.17893624305725098
# 0.2609100341796875
# 0.3574075698852539
# 0.4114081859588623
# TPO_AWS 4
# 0.01800060272216797
# 0.08400297164916992
# 0.2050004005432129
# 0.2980000972747803
# WLP_AWS 6
# 0.018997907638549805
# 0.0800008773803711
# 0.17600369453430176
# 0.25299906730651855
# 0.3359982967376709
# 0.4089984893798828
# LFS_AWS 6
# 0.019528627395629883
# 0.0840001106262207
# 0.17799997329711914
# 0.2560551166534424
# 0.35852861404418945
# 0.4440004825592041
# SSH_AWS 4
# 0.018999814987182617
# 0.08350062370300293
# 0.18500113487243652
# 0.2625000476837158
# TKL_AWS 6
# 0.017000198364257812
# 0.08352804183959961
# 0.1965010166168213
# 0.2720012664794922
# 0.35899901390075684
# 0.45200109481811523
# EPC_AWS 6
# 0.017499208450317383
# 0.07949995994567871
# 0.18449974060058594
# 0.26853132247924805
# 0.36950206756591797
# 0.44900059700012207
# TCAWS 2
# 0.11953043937683105
# 0.6410717964172363
# PHSUP2 5
# 0.12049698829650879
# 1.1554975509643555
# 1.8349976539611816
# 2.5960216522216797
# 3.353583574295044
# YLAWS 2
# 0.11949872970581055
# 0.6154990196228027
# STL_AWS 4
# 0.022501230239868164
# 0.08800053596496582
# 0.20000219345092773
# 0.2735006809234619
# NGP_AWS 4
# 0.010500431060791016
# 0.05950021743774414
# 0.12850213050842285
# 0.18853020668029785
# VP1_AWS 2
# 0.01597118377685547
# 0.07847213745117188
# HPV_AWS 2
# 0.01749873161315918
# 0.0840003490447998
# HKP_AWS 2
# 0.016969680786132812
# 0.07297229766845703
# SKW_AWS 2
# 0.012025833129882812
# 0.07699775695800781
# SE_AWS 4
# 0.01749730110168457
# 0.0794990062713623
# 0.1675262451171875
# 0.24699640274047852
# KWT_AWS 2
# 0.018999814987182617
# 0.08349967002868652
# KLC_AWS 2
# 0.017501115798950195
# 0.0950002670288086
# SSP_AWS 2
# 0.01799941062927246
# 0.09999966621398926
# WTS_AWS 2
# 0.02050185203552246
# 0.09000325202941895
# TAP_AWS 4
# 0.010498762130737305
# 0.053997039794921875
# 0.13599801063537598
# 0.2044975757598877
# PLC_AWS 4
# 0.009500265121459961
# 0.0664985179901123
# 0.14599847793579102
# 0.22153139114379883
# KAT_AWS 2
# 0.007970333099365234
# 0.041471242904663086
# BHD_AWS 2
# 0.010500192642211914
# 0.05414557456970215
# CCB_AWS 2
# 0.010501623153686523
# 0.07052922248840332
# TO_AWS 2
# 0.008471965789794922
# 0.04947090148925781
# YTS_AWS 2
# 0.0075016021728515625
# 0.041500091552734375
# NLS_AWS 2
# 0.009500503540039062
# 0.056000709533691406
# GI_AWS 2
# 0.017503023147583008
# 0.08352899551391602
# SF_AWS 2
# 0.014973640441894531
# 0.07247614860534668
# NP_AWS 2
# 0.010025978088378906
# 0.05450105667114258
# SHW_AWS 2
# 0.008996725082397461
# 0.042996883392333984
# R2C_AWS 2
# 0.009999513626098633
# 0.060002803802490234
# TMT_AWS 2
# 0.005021810531616211
# 0.03802824020385742
# SC_AWS 2
# 0.013968706130981445
# 0.06646919250488281
# SHL_AWS 2
# 0.008501052856445312
# 0.05302715301513672
# TPK_AWS 2
# 0.014974832534790039
# 0.08347320556640625
# SPAWS 1
# 0.11397171020507812

# %%
deduplicate_dfs_map = {}
for station_code in station_dfs_merge:

    agg_df = station_dfs_merge[station_code]

    agg_df = agg_df.groupby(agg_df.columns, axis=1).max()
    
    for c in agg_df.columns:
        if c[-2:] == '_c':
            agg_df = agg_df.rename(columns = {c: c[:-2]})
    print(station_code, list(agg_df.columns))
    deduplicate_dfs_map[station_code] = agg_df
# Out:
# WGL_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# CCH_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# HKS_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# SLW_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# HKO_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# HKA_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# KP_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# JKB_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# USTTB ['relative_humidity', 'station_code', 'temperature', 'time']
# USTPR ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# USTPR2 ['relative_humidity', 'station_code', 'temperature', 'time']
# PHSUP ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# CPH_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# TC_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# KSC_AWS ['relative_humidity', 'station_code', 'temperature', 'time']
# SKG_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# TUN_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# SHA_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# TYW_AWS ['relative_humidity', 'station_code', 'temperature', 'time']
# TMS_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# SEK_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# TPO_AWS ['relative_humidity', 'station_code', 'temperature', 'time']
# WLP_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# LFS_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# SSH_AWS ['relative_humidity', 'station_code', 'temperature', 'time']
# TKL_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# EPC_AWS ['relative_humidity', 'station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# TCAWS ['relative_humidity', 'station_code', 'temperature', 'time']
# PHSUP2 ['relative_humidity', 'station_code', 'temperature', 'temperature', 'time', 'wind_direction', 'wind_speed']
# YLAWS ['relative_humidity', 'station_code', 'temperature', 'time']
# STL_AWS ['station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# NGP_AWS ['station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# VP1_AWS ['station_code', 'temperature', 'time']
# HPV_AWS ['station_code', 'temperature', 'time']
# HKP_AWS ['station_code', 'temperature', 'time']
# SKW_AWS ['station_code', 'temperature', 'time']
# SE_AWS ['station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# KWT_AWS ['station_code', 'temperature', 'time']
# KLC_AWS ['station_code', 'temperature', 'time']
# SSP_AWS ['station_code', 'temperature', 'time']
# WTS_AWS ['station_code', 'temperature', 'time']
# TAP_AWS ['station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# PLC_AWS ['station_code', 'temperature', 'time', 'wind_direction', 'wind_speed']
# KAT_AWS ['station_code', 'temperature', 'time']
# BHD_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# CCB_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# TO_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# YTS_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# NLS_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# GI_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# SF_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# NP_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# SHW_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# R2C_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# TMT_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# SC_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# SHL_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# TPK_AWS ['station_code', 'time', 'wind_direction', 'wind_speed']
# SPAWS ['station_code', 'time', 'wind_direction', 'wind_speed']

# %%
# odo('accounts.csv', pd.DataFrame)

for station_code in deduplicate_dfs_map:
    print('Processing', station_code, 'of', len(deduplicate_dfs_map))
    current_df = deduplicate_dfs_map[station_code]
    current_df['time'] = current_df['time'].apply(lambda t:  time.mktime(time.strptime(t, "%Y/%m/%d %H:%M:%S")) if type(t) == str else t)
    current_df = current_df.assign(loc = [station_config_map[station_code] for _ in range(len(current_df))]) 
    
    current_df_T = current_df.T
    current_df_T_dict = current_df_T.to_dict()
    dict_arr = []
    for key in current_df_T_dict:
        dict_arr.append(current_df_T_dict[key])
    sub_hour_weather_collection.insert_many(dict_arr)
# Out:
# Processing WGL_AWS of 59
# Processing CCH_AWS of 59
# Processing HKS_AWS of 59
# Processing SLW_AWS of 59
# Processing HKO_AWS of 59
# Processing HKA_AWS of 59
# Processing KP_AWS of 59
# Processing JKB_AWS of 59
# Processing USTTB of 59
# Processing USTPR of 59
# Processing USTPR2 of 59
# Processing PHSUP of 59
# Processing CPH_AWS of 59
# Processing TC_AWS of 59
# Processing KSC_AWS of 59
# Processing SKG_AWS of 59
# Processing TUN_AWS of 59
# Processing SHA_AWS of 59
# Processing TYW_AWS of 59
# Processing TMS_AWS of 59
# Processing SEK_AWS of 59
# Processing TPO_AWS of 59
# Processing WLP_AWS of 59
# Processing LFS_AWS of 59
# Processing SSH_AWS of 59
# Processing TKL_AWS of 59
# Processing EPC_AWS of 59
# Processing TCAWS of 59
# Processing PHSUP2 of 59
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-c0ee2b7f480e> in <module>()
#       4     print('Processing', station_code, 'of', len(deduplicate_dfs_map))
#       5     current_df = deduplicate_dfs_map[station_code]
# ----> 6     current_df['time'] = current_df['time'].apply(lambda t:  time.mktime(time.strptime(t, "%Y/%m/%d %H:%M:%S")) if type(t) == str else t)
#       7     current_df = current_df.assign(loc = [station_config_map[station_code] for _ in range(len(current_df))])
#       8
#
# E:\workspace\venv3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# E:\workspace\venv3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2396         self._ensure_valid_index(value)
#    2397         value = self._sanitize_column(key, value)
# -> 2398         NDFrame._set_item(self, key, value)
#    2399
#    2400         # check if we are modifying a copy
#
# E:\workspace\venv3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    1757
#    1758     def _set_item(self, key, value):
# -> 1759         self._data.set(key, value)
#    1760         self._clear_item_cache()
#    1761
#
# E:\workspace\venv3\lib\site-packages\pandas\core\internals.py in set(self, item, value, check)
#    3729         removed_blknos = []
#    3730         for blkno, val_locs in _get_blkno_placements(blknos, len(self.blocks),
# -> 3731                                                      group=True):
#    3732             blk = self.blocks[blkno]
#    3733             blk_locs = blklocs[val_locs.indexer]
#
# E:\workspace\venv3\lib\site-packages\pandas\core\internals.py in _get_blkno_placements(blknos, blk_count, group)
#    4682
#    4683     # FIXME: blk_count is unused, but it may avoid the use of dicts in cython
# -> 4684     for blkno, indexer in lib.get_blkno_indexers(blknos, group):
#    4685         yield blkno, BlockPlacement(indexer)
#    4686
#
# pandas\_libs\lib.pyx in pandas._libs.lib.get_blkno_indexers (pandas\_libs\lib.c:25817)()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 0)

# %%
data = {'k1':[1,2,3,4,5],'name':['a','b','c','d','e'], 'mark': [11,22,33,44,55], 'loc': [[1,1],[2,1],[3,1],[4,1],[5,1]]}
data2 = {'k1':[1,2,3,6,7],'name':['a','b','c','d','e'], 'mark': [111,122,133,144,155], 'loc': [[1,1],[2,2],[2,3],[4,3],[5,3]]}
data3 = {'k1':[1,2,3,6,7],'name':['a','b','c','d','e'], 'mark': [211,222,233,244,255]}
df1 = DataFrame(data)
df2 = DataFrame(data2)
df3 = DataFrame(data3)
print(df1)
print('\n')
print(df2)
print('\n')
print(df3)

# %%
test = pd.merge(df1, df2, how='outer', on=['k1', 'name'], suffixes=('_1', '_1'))
test = pd.merge(test, df3, how='outer', on=['k1', 'name'], copy = True, suffixes=('_1', '_1'))
test = pd.merge(test, df3, how='outer', on=['k1', 'name'], copy = True, suffixes=('_1', '_1'))
test = pd.merge(test, df3, how='outer', on=['k1', 'name'], copy = True, suffixes=('_1', '_1'))
# merge_df = pd.merge(merge_df, df3, how='outer', on=['k1', 'name'], copy = True, suffixes=('_', '_'))

# for c in merge_df.columns:
#     if c[-2:] == '_c':
#         merge_df = merge_df.rename(columns = {c: c[:-2]})
# print(' ')
# print(merge_df)
test

# %%
from odo import odo

# %%
data = {'k1':[1,2,3,4,5],'name':['a','b','c','d','e'], 'mark': [11,22,33,44,55]}
data2 = {'k1':[1,2,3,6,7],'name':['a','b','c','d','e'], 'mark': [111,122,133,144,155]}
data3 = {'k1':[1,2,3,6,7],'name':['a','b','c','d','e'], 'mark': [211,222,233,244,255]}
df1 = DataFrame(data)
df2 = DataFrame(data2)
df3 = DataFrame(data3)
test = pd.merge(df1, df2, how='outer', on=['k1', 'name'], suffixes=('', '_1'))
test = pd.merge(test, df3, how='outer', on=['k1', 'name'], suffixes=('', '_1'))
test = pd.merge(test, df3, how='outer', on=['k1', 'name'], suffixes=('', '_1'))
test = pd.merge(test, df3, how='outer', on=['k1', 'name'], suffixes=('', '_1'))

# %%
test.columns

# %%
# def maxx(arr):
#     m = -99999
#     for a in arr:
#         m = a if a > m else m
#     return m
test = test.groupby(test.columns, axis=1).max()

# %%
test.T

# %%
s = '123'
s2 = 123
type(s) == str
print(type(s2) == float)
# Out:
# False
